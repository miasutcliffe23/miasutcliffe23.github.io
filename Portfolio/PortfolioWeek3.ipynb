# %% [markdown]
# Week 3: Inline data objects and visual coding

# %%
# Import pandas
import pandas as pd

# %%
# Read our csv file data 
df = pd.read_csv('Unemployment_data_3.csv')

# %%
exported_values = list(df.T.to_dict().values())

# %%
exported_values
# Out:
# [{'Country': 'FRA', 'Time': '2000-03', 'Percentage': 10.1},
#  {'Country': 'FRA', 'Time': '2000-04', 'Percentage': 9.9},
#  {'Country': 'FRA', 'Time': '2000-05', 'Percentage': 9.7},
#  {'Country': 'FRA', 'Time': '2000-06', 'Percentage': 9.5},
#  {'Country': 'FRA', 'Time': '2000-07', 'Percentage': 9.4},
#  {'Country': 'FRA', 'Time': '2000-08', 'Percentage': 9.3},
#  {'Country': 'FRA', 'Time': '2000-09', 'Percentage': 9.1},
#  {'Country': 'FRA', 'Time': '2000-10', 'Percentage': 9.0},
#  {'Country': 'FRA', 'Time': '2000-11', 'Percentage': 8.9},
#  {'Country': 'FRA', 'Time': '2000-12', 'Percentage': 8.8},
#  {'Country': 'FRA', 'Time': '2001-01', 'Percentage': 8.7},
#  {'Country': 'FRA', 'Time': '2001-02', 'Percentage': 8.7},
#  {'Country': 'FRA', 'Time': '2001-03', 'Percentage': 8.7},
#  {'Country': 'FRA', 'Time': '2001-04', 'Percentage': 8.7},
#  {'Country': 'FRA', 'Time': '2001-05', 'Percentage': 8.7},
#  {'Country': 'FRA', 'Time': '2001-06', 'Percentage': 8.8},
# ...

# %%
import json

# %%
open('unemployment_data_3.json','w').write(json.dumps(exported_values))
# Out:
# 63120
