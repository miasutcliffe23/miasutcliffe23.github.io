# %% [markdown]
# # Downloading and Editing Data from World Bank API:

# %%
# Begin by installing the packages that we need got 
import numpy as np
import pandas as pd

# %%
# Download World Bank API Packages
# !pip install world-bank-data
import world_bank_data as wb
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for world-bank-data: filename=world_bank_data-0.1.3-py3-none-any.whl size=11110 sha256=e340a8d1f09d0fbc6ab96dcd0c0f627f4b57c6bda4f9cbd7424409ae1e0a0dc5
#   Stored in directory: /root/.cache/pip/wheels/fe/17/0c/9ef630351acc5856f4a1814d96bc082eccf1cbbb779fcd1a98
# Successfully built world-bank-data
# ...

# %%
# Select the Data that we want

urbanpop = pd.DataFrame(wb.get_series('SP.URB.TOTL.IN.ZS'))
gdpcapita = pd.DataFrame(wb.get_series('NY.GDP.PCAP.CD'))
population = pd.DataFrame(wb.get_series('SP.POP.TOTL'))

# %%
urbanpop.to_csv('urbanpop.csv')

# %%
# Sort and filter the urban population data to what we want to display

urbanpop = pd.read_csv('urbanpop.csv')
urbanpop = urbanpop.drop('Series', axis=1)
urbanpop = urbanpop[urbanpop.Year > 2010]
urbanpop = urbanpop.dropna()
urbanpop = urbanpop.sort_values(by=['Country', 'Year'])
urbanpop = urbanpop.drop_duplicates(subset=['Country'], keep='last')
urbanpop = urbanpop.set_index('Country')
urbanpop.columns = ["Year", "Urban population"]
urbanpop= urbanpop.drop('Year', axis=1)

# %%
# Check that this is what we want

urbanpop
# Out:
#                              Urban population
# Country
# Afghanistan                         26.314000
# Africa Eastern and Southern         37.323697
# Africa Western and Central          48.454806
# Albania                             62.969000
# Algeria                             74.261000
# ...                                       ...
# West Bank and Gaza                  77.003000
# World                               56.477541
# Yemen, Rep.                         38.546000
# Zambia                              45.192000
# Zimbabwe                            32.303000
#
# [263 rows x 1 columns]

# %%
gdpcapita.to_csv('gdpcapita.csv')

# %%
# Sort and filter GDP capita data to what we want to display

# %%
gdpcapita = pd.read_csv('gdpcapita.csv')
gdpcapita = gdpcapita.drop('Series', axis=1)
gdpcapita = gdpcapita[gdpcapita.Year > 2010]
gdpcapita = gdpcapita.dropna()
gdpcapita = gdpcapita.sort_values(by=['Country', 'Year'])
gdpcapita = gdpcapita.drop_duplicates(subset=['Country'], keep='last')
gdpcapita = gdpcapita.set_index('Country')
gdpcapita.columns = ["Year", "GDP per Capita"]
gdpcapita= gdpcapita.drop('Year', axis=1)

# %%
# Check this is what we want

gdpcapita
# Out:
#                              GDP per Capita
# Country
# Afghanistan                      368.754614
# Africa Eastern and Southern     1537.336021
# Africa Western and Central      1757.030626
# Albania                         6492.872012
# Algeria                         3690.627878
# ...                                     ...
# West Bank and Gaza              3663.969055
# World                          12234.796802
# Yemen, Rep.                      701.714878
# Zambia                          1137.343633
# Zimbabwe                        1773.920411
#
# [261 rows x 1 columns]

# %%
# Now we have the data that we want we can merge the datasets 

urbanpop_gdpcapita = pd.merge(urbanpop, gdpcapita, how='left', on='Country')

# %%
# Check this is what we want

urbanpop_gdpcapita
# Out:
#                              Urban population  GDP per Capita
# Country
# Afghanistan                         26.314000      368.754614
# Africa Eastern and Southern         37.323697     1537.336021
# Africa Western and Central          48.454806     1757.030626
# Albania                             62.969000     6492.872012
# Algeria                             74.261000     3690.627878
# ...                                       ...             ...
# West Bank and Gaza                  77.003000     3663.969055
# World                               56.477541    12234.796802
# Yemen, Rep.                         38.546000      701.714878
# Zambia                              45.192000     1137.343633
# Zimbabwe                            32.303000     1773.920411
#
# [263 rows x 2 columns]

# %%
population.to_csv('population.csv')

# %%
population = pd.read_csv('population.csv')
population = population.drop('Series', axis=1)
population = population[population.Year > 2010]
population = population.dropna()
population = population.sort_values(by=['Country', 'Year'])
population = population.drop_duplicates(subset=['Country'], keep='last')
population = population.set_index('Country')
population.columns = ["Year", "Population"]
population= population.drop('Year', axis=1)

population
# Out:
#                                Population
# Country
# Afghanistan                  4.009946e+07
# Africa Eastern and Southern  7.029768e+08
# Africa Western and Central   4.781859e+08
# Albania                      2.811666e+06
# Algeria                      4.417797e+07
# ...                                   ...
# West Bank and Gaza           4.922749e+06
# World                        7.888409e+09
# Yemen, Rep.                  3.298164e+07
# Zambia                       1.947312e+07
# Zimbabwe                     1.599352e+07
#
# [265 rows x 1 columns]

# %%
projectchart2 = pd.merge(urbanpop_gdpcapita, population, how='left', on='Country')

projectchart2 = projectchart2[projectchart2.GDP per Capita !=50000]
# Out:
#   File "<ipython-input-28-cf8e4dd8379e>", line 3
#     projectchart2 = projectchart2[projectchart2.GDP per Capita !=50000]
#                                                     ^
# SyntaxError: invalid syntax

# %%
# Download this data to a csv file

projectchart2.to_csv('projectchart2.csv')
